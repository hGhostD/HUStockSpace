# %%
import pandas as pd
import akshare as ak
import datetime as dt
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt

# %%
now = dt.datetime.now()
today = now.strftime("%Y%m%d")
last_month_date = (now - relativedelta(months = 1)).strftime("%Y%m%d")
last_month_date
# Out:
# '20241213'

# %%
stock_hot_rank_wc_df = ak.stock_hot_rank_wc(date=today) # 个股热度
hots = stock_hot_rank_wc_df
hots.head(20)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#     序号    股票代码  股票简称      现价    涨跌幅      个股热度   个股热度排名      排名日期
# 0    1  603667  五洲新春   31.40   0.96  567797.5   1/5395  20250113
# 1    2  605033  美邦股份   25.78   9.98  516610.0   2/5395  20250113
# 2    3  002131  利欧股份    3.34  -7.99  500814.0   3/5395  20250113
# 3    4  603777   来伊份   18.48  10.00  454956.0   4/5395  20250113
# 4    5  002418  康盛股份    3.74  10.00  416264.0   5/5395  20250113
# 5    6  603015  弘讯科技   13.15  -0.30  393145.0   6/5395  20250113
# 6    7  002265  建设工业   28.02  -9.99  373755.0   7/5395  20250113
# 7    8  600601  方正科技    4.83  -7.82  353666.5   8/5395  20250113
# 8    9  300377   赢时胜   26.45  12.08  328528.0   9/5395  20250113
# 9   10  002313  日海智能    9.44  10.02  324384.0  10/5395  20250113
# 10  11  000063  中兴通讯   39.00   3.42  306854.5  11/5395  20250113
# 11  12  002917   金奥博   13.05  10.03  288797.0  12/5395  20250113
# 12  13  002582   好想你    8.40   9.95  275784.0  13/5395  20250113
# 13  14  000759  中百集团    9.16   3.15  266422.0  14/5395  20250113
# 14  15  002119  康强电子   17.40   3.39  261991.0  15/5395  20250113
# 15  16  002681  奋达科技    6.80   7.94  241649.0  16/5395  20250113
# 16  17  688256   寒武纪  719.00  -1.50  236612.0  17/5395  20250113
# 17  18  300561  汇金科技   61.20   7.37  231837.0  18/5395  20250113
# 18  19  002184  海得控制   16.77  -9.98  229596.0  19/5395  20250113
# 19  20  600128  苏豪弘业   10.52  10.04  219728.0  20/5395  20250113

# %% [markdown]
# 计算今日成交额

# %%
df = ak.stock_zh_a_spot_em()
df['成交额'].astype(float).sum() / 100000000
# Out:
# 9762.080248886099

# %% [markdown]
# 通过 stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em() 方法获取今日个股情况
# 1. 计算两市成交额
# 	a. 记录数据
# 	b. 比较数据是放量还是缩量
# 2. 对当日成交额进行排序
# 	a. 获取前 20 个股排名

# %%
df_sorted = df.sort_values(by='成交额', ascending=False)

# %%
d = df_sorted.loc[:, ['代码', '名称', '最新价', '涨跌幅', '成交额', '振幅', '量比', '换手率']]
d['成交额'] = d['成交额'] / 1e8  # 除以 1 亿
d['成交额'] = d['成交额'].map(lambda x: f'{x:.2f}亿')  # 格式化为字符串
d = d.reset_index(drop=True)
d.index += 1
d.head(50)
# Out:
#         代码     名称      最新价    涨跌幅     成交额     振幅    量比    换手率
# 1   300059   东方财富    26.27   1.43  91.95亿   2.20  0.95   2.64
# 2   000977   浪潮信息    53.62   5.45  88.55亿   7.34  1.34  11.40
# 3   000063   中兴通讯    36.71   1.55  84.63亿   4.40  0.55   5.75
# 4   688981   中芯国际    97.03   1.94  82.81亿   4.57  0.95   4.36
# 5   600839   四川长虹    11.11   8.71  75.03亿  10.67  2.59  14.87
# 6   600171   上海贝岭    45.95   5.63  62.06亿  12.51  1.67  19.72
# 48  002371   北方华创   408.39   1.21  24.82亿   2.47  0.68   1.15
# 49  000333   美的集团    76.24   2.18  24.78亿   2.65  1.44   0.47
# 50  000564   供销大集     3.27  -3.54  24.73亿   7.67  1.01   5.35

# %%
d_filtered = d.loc[d['代码'] == '000002']
d_filtered
# Out:
#          代码     名称   最新价   涨跌幅    成交额    振幅    量比   换手率
# 387  000002  万  科Ａ  7.73  0.91  6.39亿  1.31  0.76  0.85

# %%
d_filtered['量比'].values[0]
# Out:
# 0.76

# %% [markdown]
# 量比小于0.5 属于明显缩量。缩量能创新高，说明主力高度控盘，而且能排除主力出货的可能，如果正好**处于<span style="color: #FF0022;">上升</span>通道**，则吃肉的概率极大。
# 如果股票涨停量比小于 1，说明还有较大的上涨空间，次日再次涨停的概率极大。
# 如果量比大于1.5，而且突破某个重要主力位，是不可多得的买入位。

# %%
def checkVolumeRatio(item):
    print(item)
    if isinstance(item['量比'], pd.Series):
        ratio = float(item['量比'].iloc[0])
    else:
        ratio = float(item['量比'])
    print('量比:', ratio)
    if ratio < 0.5:
        print('属于明显缩量，主力高度控盘能创新高。')
    elif ratio < 1:
        print('还有较大的上涨空间，次日再次涨停的概率极大。')
    elif ratio > 1.5:
        print('如果突破了主力位，就是不可多得的买入位置。')
    else:
        print('还不符合特殊的量比数据')

# %%
def judgmentTendency(code):
    stock_individual_info_em_df = ak.stock_individual_info_em(symbol=code)
    print(stock_individual_info_em_df)
    
judgmentTendency("000002")
# Out:
#    item               value
# 0  股票代码              000002
# 1  股票简称               万  科Ａ
# 2   总股本       11930709471.0
# 3   流通股        9716935865.0
# 4   总市值  92224384210.830002
# 5  流通市值  75111914236.449997
# 6    行业               房地产开发
# 7  上市时间            19910129

# %%
checkVolumeRatio(d_filtered)
# Out:
#          代码     名称   最新价   涨跌幅    成交额    振幅    量比   换手率
# 387  000002  万  科Ａ  7.73  0.91  6.39亿  1.31  0.76  0.85
# 量比: 0.76
# 还有较大的上涨空间，次日再次涨停的概率极大。

# %%
for index, row in d.head().iterrows():
    checkVolumeRatio(row)
# Out:
# 代码     300059
# 名称       东方财富
# 最新价     26.27
# 涨跌幅      1.43
# 成交额    91.95亿
# 振幅        2.2
# 量比       0.95
# 换手率      2.64
# Name: 1, dtype: object
# 量比: 0.95
# 还有较大的上涨空间，次日再次涨停的概率极大。
# 代码     000977
# 名称       浪潮信息
# 最新价     53.62
# 涨跌幅      5.45
# 成交额    88.55亿
# 振幅       7.34
# 量比       1.34
# 换手率      11.4
# Name: 2, dtype: object
# 量比: 1.34
# 还不符合特殊的量比数据
# 代码     000063
# 名称       中兴通讯
# 最新价     36.71
# 涨跌幅      1.55
# 成交额    84.63亿
# 振幅        4.4
# 量比       0.55
# 换手率      5.75
# Name: 3, dtype: object
# 量比: 0.55
# 还有较大的上涨空间，次日再次涨停的概率极大。
# 代码     688981
# 名称       中芯国际
# 最新价     97.03
# 涨跌幅      1.94
# 成交额    82.81亿
# 振幅       4.57
# 量比       0.95
# 换手率      4.36
# Name: 4, dtype: object
# 量比: 0.95
# 还有较大的上涨空间，次日再次涨停的概率极大。
# 代码     600839
# 名称       四川长虹
# 最新价     11.11
# 5   0.93  0.08  1.12
# 6   0.69  0.06  1.21
# 7  -2.17 -0.19  1.13
# 8  -0.35 -0.03  0.75
# 9   1.88  0.16  1.34
# 10 -3.00 -0.26  1.69
# 11  1.90  0.16  2.88
# 12  0.82  0.07  1.45
# 13  0.46  0.04  1.33
# 14 -3.22 -0.28  1.98
# 15 -2.14 -0.18  1.23
# 16 -1.09 -0.09  0.90
# 17  0.00  0.00  0.72
# 18 -2.83 -0.23  1.89
# 19 -1.14 -0.09  1.20
# 20 -2.05 -0.16  1.20
# 21  0.91  0.07  0.91

# %%
bb = ak.stock_zh_a_hist(symbol="000002",period="weekly", start_date=last_month_date, end_date=today, adjust="")
bb
# Out:
#            日期    股票代码    开盘    收盘    最高    最低      成交量           成交额    振幅  \
# 0  2024-11-29  000002  8.43  8.60  8.73  8.22  5726478  4.838261e+09  6.06
# 1  2024-12-06  000002  8.53  8.68  8.78  8.45  5396436  4.652954e+09  3.84
# 2  2024-12-13  000002  8.65  8.41  8.99  8.38  9064478  7.814604e+09  7.03
# 3  2024-12-20  000002  8.42  7.82  8.45  7.80  5769045  4.640005e+09  7.73
# 4  2024-12-24  000002  7.79  7.73  7.80  7.63  2049621  1.578892e+09  2.17
#
#     涨跌幅   涨跌额   换手率
# 0  2.14  0.18  5.89
# 1  0.93  0.08  5.55
# 2 -3.11 -0.27  9.33
# 3 -7.02 -0.59  5.94
# 4 -1.15 -0.09  2.11

# %%
quantity = len(bb.head(5))
aa['收盘'].rolling(window=20).mean()
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19    8.4215
# 20    8.3855
# 21    8.3540
# Name: 收盘, dtype: float64

# %%
df.head()
# Out:
#    序号      代码    名称    最新价     涨跌幅    涨跌额        成交量           成交额     振幅  \
# 0   1  603194   N中力  53.86  165.06  33.54   364690.0  2.210692e+09  85.68
# 1   2  300040  九洲集团   8.26   20.06   1.38  1179507.0  9.313991e+08  19.48
# 2   3  300959  线上线下  52.06   20.01   8.68   136030.0  6.368824e+08  26.37
# 3   4  300843  胜蓝股份  35.87   20.01   5.98   357316.0  1.238699e+09  20.31
# 4   5  300960  通业科技  27.18   20.00   4.53    56496.0  1.507767e+08  18.85
#
#       最高  ...    量比    换手率  市盈率-动态   市净率           总市值          流通市值    涨速  \
# 0  69.99  ...   NaN  73.19   24.94  4.66  2.159786e+10  2.683760e+09 -1.41
# 1   8.26  ...  1.29  25.60   49.75  1.69  4.855311e+09  3.806006e+09  0.00
# 2  52.06  ...  2.35  26.02  250.13  3.60  4.183948e+09  2.721448e+09  0.00
# 3  35.87  ...  4.27  22.95   50.23  4.00  5.872093e+09  5.584810e+09  0.00
# 4  27.18  ...  1.96   6.08   66.40  4.66  2.790418e+09  2.527044e+09  0.00
#
#    5分钟涨跌  60日涨跌幅  年初至今涨跌幅
# 0  -1.89  165.06   165.06
# 1   0.00   57.63    49.37
# 2   0.00  109.16    45.70
# 3   0.00   55.96    56.77
# 4   0.00   45.66    26.54
#
# [5 rows x 23 columns]

# %%
stock_share_hold_change_szse_df = ak.stock_share_hold_change_szse(symbol="002771")
q = stock_share_hold_change_szse_df['变动日期'].head(50)
q
# Out:
# 0     2023-12-01
# 1     2023-11-30
# 2     2023-11-27
# 3     2023-11-16
# 4     2023-11-16
# 5     2023-11-09
# 6     2023-10-13
# 7     2023-10-10
# 8     2023-10-09
# 9     2023-10-09
# 10    2022-12-30
# 11    2022-12-29
# 12    2022-12-28
# 13    2022-12-27
# 14    2022-12-26
# 15    2022-12-23
# 16    2019-11-08
# 17    2019-10-11
# 18    2019-09-27
# 19    2019-09-27
# 20    2019-09-27
# 21    2019-09-27
# 22    2019-09-27
# 23    2019-09-26
# 24    2019-09-25
# 25    2019-09-24
# 26    2019-09-24
# 27    2019-09-23
# 28    2019-09-23
# 29    2019-09-19
# 30    2019-09-18
# 31    2019-09-18
# 32    2019-09-12
# 33    2019-09-09
# 34    2019-09-05
# 35    2019-06-25
# 36    2019-06-13
# 37    2019-06-11
# 38    2019-03-06
# 39    2018-12-06
# 40    2018-12-06
# 41    2018-12-05
# 42    2018-12-05
# 43    2018-12-05
# 44    2018-12-04
# 45    2018-12-04
# 46    2018-12-04
# 47    2018-11-02
# 48    2018-11-01
# 49    2018-10-31
# Name: 变动日期, dtype: object

# %%
# 将数据转换为 DataFrame


# 将数据转换为日期格式
q = pd.to_datetime(q)

# 提取年份和月日
years = q.dt.year
day_month = q.dt.strftime('%m-%d')

# 创建 DataFrame
df = pd.DataFrame({'Year': years, 'Day_Month': day_month})

# 创建一个新的列，将每个日期转换为一个数值，以便绘图
df['Day_Month_Numeric'] = pd.to_datetime(df['Day_Month'], format='%m-%d').dt.dayofyear

# 绘制折线图
plt.plot(df['Year'], df['Day_Month_Numeric'], marker='o')

# 添加标题和标签
plt.title('日期折线图 (年份 vs. 月日)')
plt.xlabel('年份')
plt.ylabel('月日 (数值)')

# 显示网格
plt.grid()
plt.xticks(df['Year'].unique())  # 只显示唯一的年份
plt.tight_layout()  # 自适应布局
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       1 # 将数据转换为 DataFrame
#       2
#       3
#       4 # 将数据转换为日期格式
# ----> 5 q = pd.to_datetime(q)
#       7 # 提取年份和月日
#       8 years = q.dt.year
#
# NameError: name 'q' is not defined

# %%
type(q)
# Out:
# pandas.core.series.Series

# %%
df_sorted = df.sort_values(by='振幅', ascending=False)
d = df_sorted.loc[:, ['代码', '名称', '最新价', '涨跌幅', '成交额', '振幅', '量比', '换手率']]
d = d.reset_index(drop=True)
d.index += 1
d.head(50)
# Out:
#         代码      名称     最新价     涨跌幅           成交额     振幅    量比    换手率
# 1   603194     N中力   53.86  165.06  2.210692e+09  85.68   NaN  73.19
# 2   839725    惠丰钻石   43.49    8.59  5.046772e+08  30.99  2.23  30.64
# 3   301110    青木科技   78.60   16.53  1.222602e+09  28.29  2.40  36.24
# 4   300959    线上线下   52.06   20.01  6.368824e+08  26.37  2.35  26.02
# 5   300010    豆神教育    6.95    2.51  1.905523e+09  24.34  3.09  26.01
# 6   301428    世纪恒通   44.29   19.99  7.281294e+08  23.00  1.96  30.02
# 7   301067    显盈科技   33.11   17.41  6.013098e+08  22.41  3.31  34.45
# 8   301087    可孚医疗   36.74   -0.60  6.265438e+07  21.46  1.03   1.89
# 9   688605    先锋精科   84.20   19.99  1.243162e+09  20.98  1.31  42.43
# 10  300843    胜蓝股份   35.87   20.01  1.238699e+09  20.31  4.27  22.95
# 11  300563    神宇股份   64.92   14.20  2.351750e+09  19.81  1.63  31.19
