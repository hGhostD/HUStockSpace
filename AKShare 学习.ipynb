# %%
import pandas as pd
import akshare as ak
import datetime as dt
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt

# %%
now = dt.datetime.now()
today = now.strftime("%Y%m%d")
last_month_date = (now - relativedelta(months = 1)).strftime("%Y%m%d")
last_month_date
# Out:
# '20250117'

# %%
stock_hot_rank_wc_df = ak.stock_hot_rank_wc(date=today) # 个股热度
hots = stock_hot_rank_wc_df
hots.head(20)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#     序号    股票代码  股票简称      现价    涨跌幅       个股热度   个股热度排名      排名日期
# 0    1  300251  光线传媒   29.66 -14.60  4079010.5   1/5398  20250217
# 1    2  002123  梦网科技   20.57 -10.02  2447700.0   2/5398  20250217
# 2    3  002261  拓维信息   31.78  -4.31  1599065.5   3/5398  20250217
# 3    4  600126  杭钢股份   12.25   9.96  1338125.5   4/5398  20250217
# 4    5  600633  浙数文化   19.75  10.03   989626.0   5/5398  20250217
# 5    6  000785  居然智家    5.01 -10.05   976489.0   6/5398  20250217
# 6    7  002031  巨轮智能    8.51   0.83   908535.5   7/5398  20250217
# 7    8  300718  长盛轴承   77.60  19.99   874386.0   8/5398  20250217
# 8    9  000977  浪潮信息   67.87   7.27   833951.0   9/5398  20250217
# 9   10  000818  航锦科技   36.19  10.00   757924.0  10/5398  20250217
# 10  11  600839  四川长虹   12.16  -3.87   727226.0  11/5398  20250217
# 11  12  600580  卧龙电驱   26.47   6.73   669329.0  12/5398  20250217
# 12  13  600602  云赛智联   21.12  10.00   650541.5  13/5398  20250217
# 13  14  603881   数据港   37.51  10.00   646770.0  14/5398  20250217
# 14  15  002065  东华软件   10.31  10.03   638496.0  15/5398  20250217
# 15  16  300766  每日互动   53.80   5.47   632786.5  16/5398  20250217
# 16  17  600986  浙文互联    9.80   9.99   623228.0  17/5398  20250217
# 17  18  002131  利欧股份    4.54   3.89   620772.5  18/5398  20250217
# 18  19  000034  神州数码   54.22   2.42   620159.0  19/5398  20250217
# 19  20  603501  韦尔股份  136.20   0.21   618627.0  20/5398  20250217

# %% [markdown]
# 计算今日成交额

# %%
df = ak.stock_zh_a_spot_em()
df['成交额'].astype(float).sum() / 100000000
# Out:
# 1919.0369186515002

# %% [markdown]
# 通过 stock_zh_a_spot_em_df = ak.stock_zh_a_spot_em() 方法获取今日个股情况
# 1. 计算两市成交额
# 	a. 记录数据
# 	b. 比较数据是放量还是缩量
# 2. 对当日成交额进行排序
# 	a. 获取前 20 个股排名

# %%
df_sorted = df.sort_values(by='成交额', ascending=False)

# %%
d = df_sorted.loc[:, ['代码', '名称', '最新价', '涨跌幅', '成交额', '振幅', '量比', '换手率']]
d['成交额'] = d['成交额'] / 1e8  # 除以 1 亿
d['成交额'] = d['成交额'].map(lambda x: f'{x:.2f}亿')  # 格式化为字符串
d = d.reset_index(drop=True)
d.index += 1
d.head(50)
# Out:
#         代码    名称     最新价    涨跌幅      成交额     振幅    量比    换手率
# 1   600050  中国联通    6.51   8.86  136.85亿   8.36  2.34   6.92
# 2   600126  杭钢股份   12.25   9.96   77.03亿  14.09  3.51  19.20
# 3   300674  宇信科技   30.40  14.07   57.13亿  18.72  1.87  26.58
# 4   300502   新易盛  123.30  13.11   55.44亿  12.22  2.11   7.45
# 46  300044  赛为智能    7.44   9.73   11.78亿   6.93  2.69  21.24
# 47  300547  川环科技   35.66  14.96   11.76亿  22.79  1.12  19.87
# 48  603583  捷昌驱动   34.19  10.01   11.49亿   9.97  1.35   9.15
# 49  603956   威派格    9.32  10.04   10.80亿  10.04  6.56  23.57
# 50  002010  传化智联    5.68  10.08   10.74亿   9.88  2.77   7.03

# %%
d_filtered = d.loc[d['代码'] == '002010']
d_filtered
# Out:
#         代码    名称   最新价    涨跌幅     成交额    振幅    量比   换手率
# 50  002010  传化智联  5.68  10.08  10.74亿  9.88  2.77  7.03

# %%
d_filtered['量比'].values[0]
# Out:
# 2.77

# %% [markdown]
# 量比小于0.5 属于明显缩量。缩量能创新高，说明主力高度控盘，而且能排除主力出货的可能，如果正好**处于<span style="color: #FF0022;">上升</span>通道**，则吃肉的概率极大。
# 如果股票涨停量比小于 1，说明还有较大的上涨空间，次日再次涨停的概率极大。
# 如果量比大于1.5，而且突破某个重要主力位，是不可多得的买入位。

# %%
def checkVolumeRatio(item):
    print(item)
    if isinstance(item['量比'], pd.Series):
        ratio = float(item['量比'].iloc[0])
    else:
        ratio = float(item['量比'])
    print('量比:', ratio)
    if ratio < 0.5:
        print('属于明显缩量，主力高度控盘能创新高。')
    elif ratio < 1:
        print('还有较大的上涨空间，次日再次涨停的概率极大。')
    elif ratio > 1.5:
        print('如果突破了主力位，就是不可多得的买入位置。')
    else:
        print('还不符合特殊的量比数据')

# %%
def judgmentTendency(code):
    stock_individual_info_em_df = ak.stock_individual_info_em(symbol=code)
    print(stock_individual_info_em_df)
    
judgmentTendency("000002")

# %%
checkVolumeRatio(d_filtered)

# %%
for index, row in d.head().iterrows():
    checkVolumeRatio(row)

# %%
df.iloc[0]

# %%
aa = ak.stock_zh_a_hist(symbol="000002",period="daily", start_date=last_month_date, end_date=today, adjust="qfq")
aa

# %%
bb = ak.stock_zh_a_hist(symbol="000002",period="weekly", start_date=last_month_date, end_date=today, adjust="")
bb

# %%
quantity = len(bb.head(5))
aa['收盘'].rolling(window=20).mean()

# %%
df.head()

# %%
stock_share_hold_change_szse_df = ak.stock_share_hold_change_szse(symbol="002771")
q = stock_share_hold_change_szse_df['变动日期'].head(50)
q

# %%
# 将数据转换为 DataFrame


# 将数据转换为日期格式
q = pd.to_datetime(q)

# 提取年份和月日
years = q.dt.year
day_month = q.dt.strftime('%m-%d')

# 创建 DataFrame
df = pd.DataFrame({'Year': years, 'Day_Month': day_month})

# 创建一个新的列，将每个日期转换为一个数值，以便绘图
df['Day_Month_Numeric'] = pd.to_datetime(df['Day_Month'], format='%m-%d').dt.dayofyear

# 绘制折线图
plt.plot(df['Year'], df['Day_Month_Numeric'], marker='o')

# 添加标题和标签
plt.title('日期折线图 (年份 vs. 月日)')
plt.xlabel('年份')
plt.ylabel('月日 (数值)')

# 显示网格
plt.grid()
plt.xticks(df['Year'].unique())  # 只显示唯一的年份
plt.tight_layout()  # 自适应布局
plt.show()

# %%
type(q)

# %%
df_sorted = df.sort_values(by='振幅', ascending=False)
d = df_sorted.loc[:, ['代码', '名称', '最新价', '涨跌幅', '成交额', '振幅', '量比', '换手率']]
d = d.reset_index(drop=True)
d.index += 1
d.head(50)
